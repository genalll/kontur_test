# %% [markdown]
# # Пример использования простых методов векторизации на Python
#
# Векторизуем тексты отзывов на банки с сайта banki.ru.

# %%
# !pip install pymorphy2[fast]
# Out:
# Requirement already satisfied: pymorphy2[fast] in /home/genalll/.local/lib/python3.8/site-packages (0.9.1)
# Requirement already satisfied: docopt>=0.6 in /home/genalll/.local/lib/python3.8/site-packages (from pymorphy2[fast]) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /home/genalll/.local/lib/python3.8/site-packages (from pymorphy2[fast]) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /home/genalll/.local/lib/python3.8/site-packages (from pymorphy2[fast]) (2.4.417127.4579844)
# Requirement already satisfied: DAWG>=0.8; extra == "fast" in /home/genalll/.local/lib/python3.8/site-packages (from pymorphy2[fast]) (0.8.0)

# %%
import pandas as pd
import numpy as np
import pymorphy2
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/genalll/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/genalll/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Загружаем и готовим набор данных

# %%
banks = pd.read_json('dataset/train.json', orient='records')

# %%
def preprocess(text, stop_words, punctuation_marks, morph):
    tokens = word_tokenize(text.lower())
    preprocessed_text = []
    for token in tokens:
        if token not in punctuation_marks:
            lemma = morph.parse(token)[0].normal_form
            if lemma not in stop_words:
                preprocessed_text.append(lemma)
    return preprocessed_text

# %%
punctuation_marks = ['!', ',', '(', ')', ':', '-', '?', '.', '..', '...', '«', '»', ';', '–', '--']
stop_words = stopwords.words("russian")
morph = pymorphy2.MorphAnalyzer()

# %%
banks['texts'] = banks.apply(lambda row: preprocess(row['text'], punctuation_marks, stop_words, morph), axis=1)

# %%
banks
# Out:
#              id                                               text  \
# 0     809436509  Извещение о проведении открытого конкурса в эл...
# 1     854885310  ТРЕБОВАНИЯ К СОДЕРЖАНИЮ ЗАЯВКИ участника запро...
# 2       4382157  Извещение о проведении электронного аукциона д...
# 3     184555082  Извещение о проведении электронного аукциона д...
# 4     211645258  Извещение о проведении электронного аукциона д...
# ...         ...                                                ...
# 1794  938335285  «УТВЕРЖДАЮ» Директор МУП "ПКП и ОРТ" _________...
# 1795  214609521  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ УНИТАРНОЕ ПРЕДПРИЯ...
# 1796   94811748  ДОГОВОР ПОДРЯДА № _____ «___»___________20____...
# 1797  903507299  ДОКУМЕНТАЦИЯ О ЗАКУПКЕ ЗАПРОС ПРЕДЛОЖЕНИЙ В ЭЛ...
# 1798  926039184  Государственная корпорацИя по атомной энергии ...
#
#                                      label  \
# 0         обеспечение исполнения контракта
# 1         обеспечение исполнения контракта
# 2         обеспечение исполнения контракта
# 3         обеспечение исполнения контракта
# 4         обеспечение исполнения контракта
# ...                                    ...
# 1794  обеспечение гарантийных обязательств
# 1795  обеспечение гарантийных обязательств
# 1796  обеспечение гарантийных обязательств
# 1797  обеспечение гарантийных обязательств
# 1798  обеспечение гарантийных обязательств
#
#                                          extracted_part  \
# 0     {'text': ['Размер обеспечения исполнения контр...
# 1     {'text': ['Поставщик должен предоставить обесп...
# 2     {'text': ['Размер обеспечения исполнения контр...
# 3     {'text': ['Размер обеспечения исполнения контр...
# 4     {'text': ['Размер обеспечения исполнения контр...
# ...                                                 ...
# 1794  {'text': ['Заказчиком установлено требование о...
# 1795  {'text': [''], 'answer_start': [0], 'answer_en...
# 1796  {'text': [''], 'answer_start': [0], 'answer_en...
# 1797  {'text': [''], 'answer_start': [0], 'answer_en...
# 1798  {'text': [''], 'answer_start': [0], 'answer_en...
#
#                                                   texts
# 0     [извещение, проведение, открытый, конкурс, эле...
# 1     [требование, содержание, заявка, участник, зап...
# 2     [извещение, проведение, электронный, аукцион, ...
# 3     [извещение, проведение, электронный, аукцион, ...
# 4     [извещение, проведение, электронный, аукцион, ...
# ...                                                 ...
# 1794  [утверждать, директор, муп, ``, пкп, орт, '', ...
# 1795  [федеральный, государственный, унитарный, пред...
# 1796  [договор, подряд, №, _____, ___, ___________20...
# 1797  [документация, закупка, запрос, предложение, э...
# 1798  [государственный, корпорация, атомный, энергия...
#
# [1799 rows x 5 columns]

# %% [markdown]
# ## Определяем частоту слов

# %%
from collections import Counter

# %% [markdown]
# Тестируем работу Counter

# %%
test_counter = Counter(banks['texts'][0])

# %%
test_counter
# Out:
# Counter({'извещение': 2,
#          'проведение': 1,
#          'открытый': 2,
#          'конкурс': 2,
#          'электронный': 1,
#          'форма': 1,
#          'закупка': 9,
#          '№0328300032822000806': 1,
#          'общий': 1,
#          'информация': 2,
#          'номер': 4,
#          '0328300032822000806': 1,
#          'наименование': 2,
#          'объект': 1,
#          'поставка': 1,
#          'продукт': 1,
#          'питание': 1,
#          'способ': 3,
#          'определение': 1,
#          'поставщик': 1,
#          'подрядчик': 1,
#          'исполнитель': 1,
#          'бль': 1,
#          'порядок': 3,
#          'внесение': 2,
#          'денежный': 3,
#          'средство': 4,
#          'качество': 1,
#          'обеспечение': 10,
#          'заявка': 4,
#          'участие': 3,
#          'также': 1,
#          'условие': 2,
#          'гарантия': 8,
#          'предоставляться': 2,
#          'участник': 4,
#          'вид': 1,
#          'независимый': 7,
#          'предусмотреть': 1,
#          'ст': 6,
#          '45': 3,
#          'федеральный': 6,
#          'закон': 7,
#          '№': 7,
#          '44-фз': 7,
#          'выбор': 1,
#          'осуществляться': 1,
#          'самостоятельно': 2,
#          'срок': 5,
#          'действие': 3,
#          'должный': 3,
#          'составлять': 1,
#          'менее': 2,
#          'месяц': 2,
#          'дата': 1,
#          'окончание': 1,
#          'подача': 1,
#          'соответствие': 7,
#          'ч': 2,
#          '5': 1,
#          '44': 1,
#          'реквизит': 1,
#          'счёт': 5,
#          'п.16': 1,
#          '1': 2,
#          '42': 1,
#          '``': 5,
#          'расчётный': 1,
#          "''": 5,
#          '00000000000000000000': 1,
#          'лицевой': 1,
#          'смотреть': 1,
#          'прилагать': 1,
#          'документ': 2,
#          'бик': 1,
#          '000000000': 1,
#          'кредитный': 1,
#          'организация': 1,
#          'корреспондентский': 1,
#          'исполнение': 7,
#          'контракт': 8,
#          'требоваться': 1,
#          'размер': 1,
#          '6593.25': 1,
#          'российский': 2,
#          'рубль': 1,
#          'требование': 5,
#          'гарантийный': 2,
#          'обязательство': 3,
#          'мочь': 1,
#          'обеспечиваться': 1,
#          'предоставление': 2,
#          'соответствовать': 1,
#          'указанный': 1,
#          'заказчик': 2,
#          'который': 3,
#          'законодательство': 1,
#          'федерация': 1,
#          'учитываться': 1,
#          'операция': 1,
#          'поступать': 1,
#          'определяться': 1,
#          'заключаться': 1,
#          'превышать': 1,
#          'предусмотренный': 1,
#          'обеспечить': 1,
#          'число': 1,
#          'случай': 1,
#          'изменение': 1,
#          '95': 1,
#          'подтверждать': 2,
#          'дополнительный': 1,
#          'исполнить': 1,
#          'договор': 1,
#          '2': 1,
#          'акт': 1,
#          'приёмка': 1,
#          'оказать': 2,
#          'услуга': 2,
#          'поставить': 2,
#          'товар': 2,
#          'цена': 1,
#          '4': 1})

# %%
test_counter.most_common(10)
# Out:
# [('обеспечение', 10),
#  ('закупка', 9),
#  ('гарантия', 8),
#  ('контракт', 8),
#  ('независимый', 7),
#  ('закон', 7),
#  ('№', 7),
#  ('44-фз', 7),
#  ('соответствие', 7),
#  ('исполнение', 7)]

# %% [markdown]
# Считаем частоту слов во всех отзывах

# %%
words = Counter()

# %%
for txt in banks['texts']:
    words.update(txt)

# %% [markdown]
# Количество слов в отзывах

# %%
len(words)
# Out:
# 16330

# %% [markdown]
# Самые популярные слова

# %%
words.most_common(10)
# Out:
# [('обеспечение', 12488),
#  ('контракт', 10955),
#  ('исполнение', 9482),
#  ('договор', 8227),
#  ('закупка', 7565),
#  ('заказчик', 5095),
#  ('обязательство', 4977),
#  ('требование', 4696),
#  ('гарантия', 4624),
#  ('гарантийный', 3763)]

# %% [markdown]
# ## Создаем словарь, упорядоченный по частоте
#
# В словаре будем использовать 2 специальных кода:
# - Код заполнитель: 0
# - Неизвестное слово: 1
#
# Нумерация слов в словаре начинается с 2.

# %%
# Словарь, отображающий слова в коды
word_to_index = dict()
# Словарь, отображающий коды в слова
index_to_word = dict()

# %% [markdown]
# Максимальное количество обрабатываемых слов

# %%
max_words = 10000

# %% [markdown]
# Создаем словари

# %%
for i, word in enumerate(words.most_common(max_words - 2)):
    word_to_index[word[0]] = i + 2
    index_to_word[i + 2] = word[0]

# %%
word_to_index
# Out:
# {'обеспечение': 2,
#  'контракт': 3,
#  'исполнение': 4,
#  'договор': 5,
#  'закупка': 6,
#  'заказчик': 7,
#  'обязательство': 8,
#  'требование': 9,
#  'гарантия': 10,
#  'гарантийный': 11,
#  '№': 12,
#  'счёт': 13,
#  'размер': 14,
#  'товар': 15,
#  'срок': 16,
#  'участник': 17,
#  'который': 18,
#  'цена': 19,
#  'соответствие': 20,
#  'закон': 21,
#  '``': 22,
#  "''": 23,
#  'независимый': 24,
#  'поставщик': 25,
#  'средство': 26,
#  'работа': 27,
#  'предоставление': 28,
#  'электронный': 29,
#  'случай': 30,
#  'заявка': 31,
#  'услуга': 32,
#  'извещение': 33,
#  'номер': 34,
#  '%': 35,
#  'настоящий': 36,
#  'федеральный': 37,
#  'денежный': 38,
#  'статья': 39,
#  '1': 40,
#  '44-фз': 41,
#  'г.': 42,
#  'российский': 43,
#  'предусмотреть': 44,
#  'порядок': 45,
#  'информация': 46,
#  'должный': 47,
#  'форма': 48,
#  'начальный': 49,
#  'максимальный': 50,
#  'государственный': 51,
#  'проведение': 52,
#  'наименование': 53,
#  'аукцион': 54,
#  'указанный': 55,
#  'заключаться': 56,
#  'поставка': 57,
#  'документация': 58,
#  'способ': 59,
#  'подрядчик': 60,
#  'качество': 61,
#  'год': 62,
#  'часть': 63,
#  'внесение': 64,
#  'составлять': 65,
#  '5': 66,
#  'рубль': 67,
#  'такой': 68,
#  'установить': 69,
#  'федерация': 70,
#  'сторона': 71,
#  'действие': 72,
#  'реквизит': 73,
#  'требоваться': 74,
#  'заключение': 75,
#  'участие': 76,
#  'банк': 77,
#  'банковский': 78,
#  'система': 79,
#  'лицо': 80,
#  'муниципальный': 81,
#  'документ': 82,
#  '2': 83,
#  'день': 84,
#  'проект': 85,
#  'условие': 86,
#  'запрос': 87,
#  'менее': 88,
#  'соответствовать': 89,
#  'учреждение': 90,
#  'исполнитель': 91,
#  'контрактный': 92,
#  'предусмотренный': 93,
#  '2022': 94,
#  'сумма': 95,
#  '3': 96,
#  'объект': 97,
#  'дата': 98,
#  'определяться': 99,
#  'область': 100,
#  'организация': 101,
#  'бик': 102,
#  'приложение': 103,
#  'превышать': 104,
#  'ст': 105,
#  'нужда': 106,
#  'общий': 107,
#  'законодательство': 108,
#  'предоставляться': 109,
#  '45': 110,
#  'установленный': 111,
#  'предоставить': 112,
#  'результат': 113,
#  'котировка': 114,
#  'пункт': 115,
#  'самостоятельно': 116,
#  'положение': 117,
#  'расчётный': 118,
#  'процент': 119,
#  'обеспечиваться': 120,
#  'месяц': 121,
#  'вид': 122,
#  'являться': 123,
#  'число': 124,
#  'м.п': 125,
#  'осуществление': 126,
#  '96': 127,
#  '___': 128,
#  'сфера': 129,
#  'платёжный': 130,
#  'предложение': 131,
#  'основание': 132,
#  'лицевой': 133,
#  'раздел': 134,
#  'пять': 135,
#  'вправе': 136,
#  'адрес': 137,
#  'операция': 138,
#  'казначейский': 139,
#  'выполнение': 140,
#  '4': 141,
#  '10': 142,
#  'штраф': 143,
#  'учёт': 144,
#  'кредитный': 145,
#  'учитываться': 146,
#  'поступать': 147,
#  'бюджетный': 148,
#  'аванс': 149,
#  'корреспондентский': 150,
#  'также': 151,
#  'наличие': 152,
#  'устанавливаться': 153,
#  'г': 154,
#  'определение': 155,
#  'изменение': 156,
#  'далее': 157,
#  'отказ': 158,
#  'именовать': 159,
#  '05.04.2013': 160,
#  'утверждать': 161,
#  '0.00': 162,
#  'предоставлять': 163,
#  'течение': 164,
#  'сопровождение': 165,
#  'код': 166,
#  '30': 167,
#  'дополнительный': 168,
#  ']': 169,
#  'подпись': 170,
#  'победитель': 171,
#  'выдать': 172,
#  'действовать': 173,
#  'ч': 174,
#  'единица': 175,
#  'ненадлежащий': 176,
#  'путём': 177,
#  'ограничение': 178,
#  'директор': 179,
#  'предложить': 180,
#  'право': 181,
#  'копейка': 182,
#  'республика': 183,
#  'дальнейший': 184,
#  'один': 185,
#  'технический': 186,
#  'неустойка': 187,
#  'мочь': 188,
#  'россия': 189,
#  'предмет': 190,
#  '[': 191,
#  'пеня': 192,
#  '95': 193,
#  'следующий': 194,
#  'исключение': 195,
#  'акт': 196,
#  'подача': 197,
#  '6': 198,
#  'односторонний': 199,
#  'подписание': 200,
#  'обеспечить': 201,
#  'оплата': 202,
#  'место': 203,
#  'платёж': 204,
#  'осуществляться': 205,
#  'оборудование': 206,
#  '37': 207,
#  'ао': 208,
#  'характеристика': 209,
#  '0': 210,
#  'руб': 211,
#  '1.': 212,
#  'оказание': 213,
#  'получатель': 214,
#  'либо': 215,
#  'решение': 216,
#  'закупочный': 217,
#  'инна': 218,
#  'субъект': 219,
#  'отделение': 220,
#  'указать': 221,
#  'тысяча': 222,
#  'обоснование': 223,
#  'производитель': 224,
#  'иной': 225,
#  'сентябрь': 226,
#  'окончание': 227,
#  'гарант': 228,
#  'отдельный': 229,
#  'двадцать': 230,
#  'город': 231,
#  'перечисление': 232,
#  'допуск': 233,
#  'неисполнение': 234,
#  'подтверждать': 235,
#  '__________': 236,
#  'малое': 237,
#  'кпп': 238,
#  'обслуживание': 239,
#  'возврат': 240,
#  'перечень': 241,
#  'правительство': 242,
#  'россии//уфк': 243,
#  'содержание': 244,
#  'ндс': 245,
#  'заключить': 246,
#  'ул': 247,
#  '____': 248,
#  'рабочий': 249,
#  'информационный': 250,
#  '__': 251,
#  'предпринимательство': 252,
#  'приёмка': 253,
#  '7': 254,
#  'уплата': 255,
#  'казённый': 256,
#  '<': 257,
#  '20__': 258,
#  'свой': 259,
#  '>': 260,
#  '________': 261,
#  'площадка': 262,
#  'единый': 263,
#  'москва': 264,
#  'описание': 265,
#  'n': 266,
#  '№44-фз': 267,
#  'рф': 268,
#  'открытый': 269,
#  'объём': 270,
#  'выполнить': 271,
#  'среднее': 272,
#  '25': 273,
#  'протокол': 274,
#  'обязать': 275,
#  '______________': 276,
#  'городской': 277,
#  'применяться': 278,
#  'отсутствовать': 279,
#  'момент': 280,
#  'идентификационный': 281,
#  'безотзывный': 282,
#  'центр': 283,
#  'автономный': 284,
#  'район': 285,
#  'стоимость': 286,
#  'состав': 287,
#  'отношение': 288,
#  '8': 289,
#  'время': 290,
#  'постановление': 291,
#  'расторжение': 292,
#  'филиал': 293,
#  'п': 294,
#  'юридический': 295,
#  'здравоохранение': 296,
#  'этап': 297,
#  'процедура': 298,
#  'выплата': 299,
#  'медицинский': 300,
#  'край': 301,
#  'конкурс': 302,
#  'десять': 303,
#  '8.1.': 304,
#  'подписать': 305,
#  'цель': 306,
#  '00': 307,
#  'предприятие': 308,
#  'конкурентный': 309,
#  'иностранный': 310,
#  'гу': 311,
#  'применение': 312,
#  'недостаток': 313,
#  'связь': 314,
#  'поздний': 315,
#  'назначение': 316,
#  'ремонт': 317,
#  '20': 318,
#  'установление': 319,
#  '8.2.': 320,
#  'количество': 321,
#  'получение': 322,
#  '12': 323,
#  'управление': 324,
#  'представить': 325,
#  'измерение': 326,
#  'расчёт': 327,
#  'обеспечивать': 328,
#  'ниже': 329,
#  '________________': 330,
#  'раз': 331,
#  '_____________': 332,
#  'московский': 333,
#  'общество': 334,
#  'выбор': 335,
#  'согласно': 336,
#  'уфк': 337,
#  'унитарный': 338,
#  'сведение': 339,
#  'больница': 340,
#  'запрет': 341,
#  'нмц': 342,
#  'поставить': 343,
#  'позиция': 344,
#  'обстоятельство': 345,
#  'содержать': 346,
#  'возмещение': 347,
#  '24': 348,
#  '14': 349,
#  'б': 350,
#  'питание': 351,
#  'полтора': 352,
#  'новый': 353,
#  '/': 354,
#  'указание': 355,
#  'эксплуатация': 356,
#  'пао': 357,
#  'продукт': 358,
#  'прикрепить': 359,
#  'соответствующий': 360,
#  'ранее': 361,
#  'возможность': 362,
#  'мера': 363,
#  'внести': 364,
#  '16': 365,
#  '___________': 366,
#  'итого': 367,
#  'надлежащий': 368,
#  'л/с': 369,
#  '_______': 370,
#  'реестр': 371,
#  'расход': 372,
#  'соблюдение': 373,
#  'имя': 374,
#  '15': 375,
#  'значение': 376,
#  'комиссия': 377,
#  'обязанность': 378,
#  'итог': 379,
#  'указываться': 380,
#  '_____________________': 381,
#  'утвердить': 382,
#  'содержаться': 383,
#  'начислить': 384,
#  '44': 385,
#  '2023': 386,
#  'округ': 387,
#  'письменный': 388,
#  'валюта': 389,
#  'включая': 390,
#  'убыток': 391,
#  'карта': 392,
#  'лот': 393,
#  'финансовый': 394,
#  'использование': 395,
#  '13': 396,
#  'самарский': 397,
#  'оценка': 398,
#  'материал': 399,
#  '2024': 400,
#  'принятие': 401,
#  'саха': 402,
#  'снизить': 403,
#  'покупатель': 404,
#  'санкт-петербург': 405,
#  'генеральный': 406,
#  '_____': 407,
#  'он': 408,
#  'выполнять': 409,
#  'тридцать': 410,
#  'исполнить': 411,
#  'подлежать': 412,
#  'изменить': 413,
#  'файл': 414,
#  'правило': 415,
#  'другой': 416,
#  'задание': 417,
#  'рассмотрение': 418,
#  'прилагать': 419,
#  'включить': 420,
#  'принять': 421,
#  'государство': 422,
#  'устранение': 423,
#  'три': 424,
#  '9': 425,
#  'календарный': 426,
#  'дефект': 427,
#  '_______________': 428,
#  'данный': 429,
#  '____________': 430,
#  '___________________': 431,
#  'приказ': 432,
#  'смотреть': 433,
#  '31': 434,
#  'р/с': 435,
#  'соглашение': 436,
#  'помещение': 437,
#  '@': 438,
#  'гражданский': 439,
#  '2.': 440,
#  'специальный': 441,
#  'ход': 442,
#  'кодекс': 443,
#  'администрация': 444,
#  '_________': 445,
#  'подпункт': 446,
#  'акционерный': 447,
#  'происхождение': 448,
#  'основный': 449,
#  'поставлять': 450,
#  '*': 451,
#  'строительство': 452,
#  '______': 453,
#  'изделие': 454,
#  'заместитель': 455,
#  'оказывать': 456,
#  'размещение': 457,
#  'иметь': 458,
#  'начальник': 459,
#  'почтовый': 460,
#  'быть': 461,
#  'каждый': 462,
#  'врач': 463,
#  'нарушение': 464,
#  'оформление': 465,
#  'нахождение': 466,
#  'почта': 467,
#  'финансы': 468,
#  'преимущество': 469,
#  '0,5': 470,
#  'сила': 471,
#  'полный': 472,
#  'министерство': 473,
#  'продукция': 474,
#  '8.3.': 475,
#  '____________________': 476,
#  'два': 477,
#  '22': 478,
#  '2013': 479,
#  '000000000': 480,
#  'отсутствие': 481,
#  'главный': 482,
#  'якутия': 483,
#  'устанавливать': 484,
#  '6.1.': 485,
#  'потребовать': 486,
#  '00000000000000000000': 487,
#  'должность': 488,
#  'особенность': 489,
#  'образование': 490,
#  'облагаться': 491,
#  '11': 492,
#  'дать': 493,
#  'бенефициар': 494,
#  'согласовать': 495,
#  'апрель': 496,
#  'общеобразовательный': 497,
#  'осуществлять': 498,
#  'капитальный': 499,
#  '1.1.': 500,
#  'ценовый': 501,
#  'низкий': 502,
#  'антидемпинговый': 503,
#  'жилой': 504,
#  '42': 505,
#  'направить': 506,
#  'руководитель': 507,
#  'производиться': 508,
#  '�': 509,
#  'взамен': 510,
#  '223-фз': 511,
#  'замена': 512,
#  '_________________': 513,
#  'период': 514,
#  '№____': 515,
#  '6.2': 516,
#  'понести': 517,
#  'физический': 518,
#  '6.1': 519,
#  'служба': 520,
#  '0,50': 521,
#  '__________________': 522,
#  'контактный': 523,
#  'тип': 524,
#  'клинический': 525,
#  'ущерб': 526,
#  'происходить': 527,
#  'аномально': 528,
#  'центральный': 529,
#  'сеть': 530,
#  'критерий': 531,
#  'd0': 532,
#  'кредит': 533,
#  'выдача': 534,
#  'подлежащее': 535,
#  'лекарственный': 536,
#  'препарат': 537,
#  'обязываться': 538,
#  'уполномоченный': 539,
#  'начало': 540,
#  'п.16': 541,
#  'уведомление': 542,
#  'п/п': 543,
#  'поручение': 544,
#  '0,00': 545,
#  'ответственность': 546,
#  'подведение': 547,
#  'любой': 548,
#  'признаваться': 549,
#  '2025': 550,
#  'телефон': 551,
#  'фонд': 552,
#  'орган': 553,
#  'приоритет': 554,
#  'кбк': 555,
#  '9.2.': 556,
#  '1,5': 557,
#  'оказать': 558,
#  'к/с': 559,
#  'еис': 560,
#  '3.': 561,
#  'направление': 562,
#  'факт': 563,
#  'нмцк': 564,
#  '№1': 565,
#  'уклониться': 566,
#  'заключать': 567,
#  'торговый': 568,
#  'территория': 569,
#  'уменьшить': 570,
#  'разъяснение': 571,
#  'россеть': 572,
#  'собственный': 573,
#  'использовать': 574,
#  'увеличить': 575,
#  'окпд2': 576,
#  'разместить': 577,
#  'причинить': 578,
#  'огрн': 579,
#  'семь': 580,
#  '18': 581,
#  'освобождаться': 582,
#  'млн': 583,
#  'освобождать': 584,
#  '50': 585,
#  'фамилия': 586,
#  'эквивалентный': 587,
#  'контракта.': 588,
#  'обязательный': 589,
#  'развитие': 590,
#  '17': 591,
#  'сайт': 592,
#  'авансовый': 593,
#  'гбуз': 594,
#  'октмый': 595,
#  'footnoteref:16': 596,
#  'финансирование': 597,
#  '5.00': 598,
#  'образовательный': 599,
#  'вместе': 600,
#  'ктереть': 601,
#  'уклонение': 602,
#  'снижение': 603,
#  'окончательный': 604,
#  '2022г': 605,
#  '000': 606,
#  '21': 607,
#  'возвращаться': 608,
#  'минфин': 609,
#  '№2': 610,
#  'икз': 611,
#  'дом': 612,
#  'нижеследующий': 613,
#  'претензия': 614,
#  'обусловить': 615,
#  'единственный': 616,
#  'представляться': 617,
#  'главное': 618,
#  'уплатить': 619,
#  'последний': 620,
#  'оператор': 621,
#  'первоначально': 622,
#  'первый': 623,
#  'фактически': 624,
#  'нести': 625,
#  '·': 626,
#  'официальный': 627,
#  'муп': 628,
#  '9.3.': 629,
#  'областной': 630,
#  '_______________________': 631,
#  'второй': 632,
#  'сто': 633,
#  'оформить': 634,
#  'сократить': 635,
#  '8.': 636,
#  'связанный': 637,
#  'и/ить': 638,
#  'непосредственно': 639,
#  'отвечать': 640,
#  'гауз': 641,
#  '1.1': 642,
#  'последующий': 643,
#  'ввод': 644,
#  '26': 645,
#  'распространяться': 646,
#  'устав': 647,
#  'пятьдесят': 648,
#  'проводиться': 649,
#  'принципал': 650,
#  'фгуп': 651,
#  'атомный': 652,
#  'считаться': 653,
#  'определённый': 654,
#  'ii': 655,
#  'viii': 656,
#  'новосибирский': 657,
#  'копа': 658,
#  'отбор': 659,
#  'приобретение': 660,
#  'социальный': 661,
#  '126н': 662,
#  '04.06.2018': 663,
#  'июль': 664,
#  'концерн': 665,
#  'башкортостан': 666,
#  'i.': 667,
#  'добросовестность': 668,
#  'примечание': 669,
#  'департамент': 670,
#  'мп': 671,
#  'фио': 672,
#  'субподрядчик': 673,
#  'этп': 674,
#  'красноярский': 675,
#  'отчётный': 676,
#  'председатель': 677,
#  '__________________________': 678,
#  '19': 679,
#  'госкорпорация': 680,
#  'миллион': 681,
#  '9.1.': 682,
#  '№3': 683,
#  'детский': 684,
#  '100': 685,
#  'инструкция': 686,
#  'третий': 687,
#  'спецификация': 688,
#  'показатель': 689,
#  'деятельность': 690,
#  'производство': 691,
#  'шесть': 692,
#  'фз': 693,
#  'просрочка': 694,
#  'вариант': 695,
#  'ханты-мансийский': 696,
#  '4.': 697,
#  'правовой': 698,
#  'р': 699,
#  'так': 700,
#  'привести': 701,
#  'краснодарский': 702,
#  'ограниченный': 703,
#  'необходимый': 704,
#  'допускаться': 705,
#  'безопасность': 706,
#  'невозможность': 707,
#  'вследствие': 708,
#  'непреодолимый': 709,
#  '925': 710,
#  'шестьдесят': 711,
#  'page': 712,
#  'необходимо': 713,
#  'подтверждение': 714,
#  'предварительный': 715,
#  'ленинградский': 716,
#  '______________________': 717,
#  'промышленный': 718,
#  'якутск': 719,
#  'автомобильный': 720,
#  'усиленный': 721,
#  'итоговый': 722,
#  'уменьшение': 723,
#  '10.00': 724,
#  'школа': 725,
#  '10.': 726,
#  'регламент': 727,
#  'челябинск': 728,
#  '_________________________': 729,
#  'подать': 730,
#  'конкурсный': 731,
#  'росатом': 732,
#  'окпо': 733,
#  'страна': 734,
#  '244': 735,
#  'причина': 736,
#  '23': 737,
#  'краевой': 738,
#  'организатор': 739,
#  'допускать': 740,
#  'подтверждаться': 741,
#  'функциональный': 742,
#  'здание': 743,
#  'обучение': 744,
#  'краткий': 745,
#  'вина': 746,
#  'свердловский': 747,
#  'специалист': 748,
#  'признание': 749,
#  'заполнение': 750,
#  '60': 751,
#  'гбу': 752,
#  'краснодар': 753,
#  'раздельный': 754,
#  'тело': 755,
#  'сверка': 756,
#  '7.': 757,
#  '7.1.': 758,
#  '7.14.': 759,
#  'экономический': 760,
#  'ф.и.ый': 761,
#  'станция': 762,
#  'включаться': 763,
#  'четыре': 764,
#  'сопоставление': 765,
#  'северо-западный': 766,
#  'передача': 767,
#  'посредством': 768,
#  '7.2.': 769,
#  'институт': 770,
#  'выявить': 771,
#  'гарантировать': 772,
#  'национальный': 773,
#  'iii': 774,
#  'коммерческий': 775,
#  'нмцд': 776,
#  'гау': 777,
#  'квартира': 778,
#  '1000': 779,
#  'отделение-нб': 780,
#  '33': 781,
#  'получить': 782,
#  'разногласие': 783,
#  'плюс': 784,
#  'доверенность': 785,
#  'росэнергоатом': 786,
#  'печать': 787,
#  'одновременно': 788,
#  '________________________': 789,
#  'включать': 790,
#  '9.': 791,
#  'представлять': 792,
#  'отдел': 793,
#  'монтаж': 794,
#  '00000000000000000510': 795,
#  'реестровый': 796,
#  '№4': 797,
#  '1.2.': 798,
#  'http': 799,
#  '2.1.': 800,
#  'ооо': 801,
#  '20___': 802,
#  'аукционный': 803,
#  '08.11.2013': 804,
#  'гражданско-правовой': 805,
#  'фгб': 806,
#  'составить': 807,
#  'правопреемство': 808,
#  'ответственный': 809,
#  'договорный': 810,
#  'направлять': 811,
#  'перечисленный': 812,
#  'н': 813,
#  'югра': 814,
#  'признать': 815,
#  'обеспечительный': 816,
#  'экспертиза': 817,
#  'высокий': 818,
#  'инн/кпп': 819,
#  'восемьдесят': 820,
#  'калининградский': 821,
#  'девять': 822,
#  'комитет': 823,
#  'ребёнок': 824,
#  'нижний': 825,
#  'нормативно-правовой': 826,
#  'с.': 827,
#  'налоговый': 828,
#  'весь': 829,
#  'истечение': 830,
#  'гуп': 831,
#  'мособлгаз': 832,
#  'расходный': 833,
#  'привлечение': 834,
#  'рамка': 835,
#  'списание': 836,
#  '29': 837,
#  'информационно-телекоммуникационный': 838,
#  'устранить': 839,
#  'улица': 840,
#  'интернет': 841,
#  'заказ': 842,
#  'инициал': 843,
#  '014030106': 844,
#  'инвалид': 845,
#  'новгород': 846,
#  '5,00': 847,
#  'произойти': 848,
#  'евразийский': 849,
#  'член': 850,
#  '//': 851,
#  'девяносто': 852,
#  'судебный': 853,
#  'сорок': 854,
#  'факс': 855,
#  'квалифицировать': 856,
#  'хозяйство': 857,
#  'данные': 858,
#  'кв': 859,
#  '2011': 860,
#  'изготовитель': 861,
#  'красноярск': 862,
#  'пятнадцать': 863,
#  'цфо//уфк': 864,
#  'представитель': 865,
#  'россии//': 866,
#  '10.1.': 867,
#  '7.15.': 868,
#  'технологический': 869,
#  '7.16.': 870,
#  '06': 871,
#  'проектный': 872,
#  'пятьсот': 873,
#  'строительно-монтажный': 874,
#  'сбербанк': 875,
#  'лицензия': 876,
#  'осуществить': 877,
#  'несколько': 878,
#  'нижегородский': 879,
#  'полностью': 880,
#  'отзыв': 881,
#  'установка': 882,
#  'корпорация': 883,
#  'триста': 884,
#  'необходимость': 885,
#  '11.': 886,
#  'восемь': 887,
#  'предъявлять': 888,
#  '7.17.': 889,
#  'поручительство': 890,
#  'мсп': 891,
#  'совместно': 892,
#  '7.3.': 893,
#  'инженерный': 894,
#  'и.о': 895,
#  'текст': 896,
#  'оригинал': 897,
#  'залог': 898,
#  'продавец': 899,
#  '7.2': 900,
#  'средний': 901,
#  'формирование': 902,
#  '6.': 903,
#  'двести': 904,
#  'поступить': 905,
#  'квалификационный': 906,
#  'спб': 907,
#  'знак': 908,
#  '9.4.': 909,
#  'помощь': 910,
#  '000,00': 911,
#  'ед': 912,
#  'вносить': 913,
#  'налог': 914,
#  'дорога': 915,
#  '8.4.': 916,
#  'четыреста': 917,
#  'восемьсот': 918,
#  '40102810945370000005': 919,
#  '5.': 920,
#  '34': 921,
#  'подавать': 922,
#  '+7': 923,
#  'соответственно': 924,
#  'калининград': 925,
#  'арбитражный': 926,
#  'непредоставление': 927,
#  '109': 928,
#  '110': 929,
#  'соисполнитель': 930,
#  'подраздел': 931,
#  'статус': 932,
#  'штука': 933,
#  '________________________________': 934,
#  'включительно': 935,
#  '1005': 936,
#  'перечисляться': 937,
#  'продлеваться': 938,
#  'устройство': 939,
#  'липецкий': 940,
#  'суд': 941,
#  '21.': 942,
#  'бакалея': 943,
#  'прилагаться': 944,
#  '18.07.2011': 945,
#  'относительно': 946,
#  'южный': 947,
#  'ответ': 948,
#  'алтайский': 949,
#  'семьдесят': 950,
#  'индивидуальный': 951,
#  'кемерово': 952,
#  'исчисляться': 953,
#  'образец': 954,
#  'минздрав': 955,
#  'входящий': 956,
#  '12.': 957,
#  'фгбоу': 958,
#  '10.2.': 959,
#  'оформляться': 960,
#  'саратовский': 961,
#  'местный': 962,
#  'наступление': 963,
#  'тульский': 964,
#  'подряд': 965,
#  'р/сча': 966,
#  'авансирование': 967,
#  'ресурс': 968,
#  'распоряжение': 969,
#  'севастополь': 970,
#  'корпус': 971,
#  'согласование': 972,
#  'одновременный': 973,
#  'научно-исследовательский': 974,
#  'подготовка': 975,
#  'письмо': 976,
#  '1.3.': 977,
#  'глава': 978,
#  'отребовать': 979,
#  '144': 980,
#  'какой-либо': 981,
#  'сметный': 982,
#  'тепловой': 983,
#  'энергия': 984,
#  '___________________________': 985,
#  'поликлиника': 986,
#  'поле': 987,
#  '010349101': 988,
#  'м': 989,
#  'начисляться': 990,
#  'использоваться': 991,
#  'удовлетворение': 992,
#  'сочи': 993,
#  'комплекс': 994,
#  '1.2': 995,
#  'начинать': 996,
#  'удержание': 997,
#  '05': 998,
#  'среди': 999,
#  'источник': 1000,
#  'л': 1001,
#  ...}

# %%
index_to_word
# Out:
# {2: 'обеспечение',
#  3: 'контракт',
#  4: 'исполнение',
#  5: 'договор',
#  6: 'закупка',
#  7: 'заказчик',
#  8: 'обязательство',
#  9: 'требование',
#  10: 'гарантия',
#  11: 'гарантийный',
#  12: '№',
#  13: 'счёт',
#  14: 'размер',
#  15: 'товар',
#  16: 'срок',
#  17: 'участник',
#  18: 'который',
#  19: 'цена',
#  20: 'соответствие',
#  21: 'закон',
#  22: '``',
#  23: "''",
#  24: 'независимый',
#  25: 'поставщик',
#  26: 'средство',
#  27: 'работа',
#  28: 'предоставление',
#  29: 'электронный',
#  30: 'случай',
#  31: 'заявка',
#  32: 'услуга',
#  33: 'извещение',
#  34: 'номер',
#  35: '%',
#  36: 'настоящий',
#  37: 'федеральный',
#  38: 'денежный',
#  39: 'статья',
#  40: '1',
#  41: '44-фз',
#  42: 'г.',
#  43: 'российский',
#  44: 'предусмотреть',
#  45: 'порядок',
#  46: 'информация',
#  47: 'должный',
#  48: 'форма',
#  49: 'начальный',
#  50: 'максимальный',
#  51: 'государственный',
#  52: 'проведение',
#  53: 'наименование',
#  54: 'аукцион',
#  55: 'указанный',
#  56: 'заключаться',
#  57: 'поставка',
#  58: 'документация',
#  59: 'способ',
#  60: 'подрядчик',
#  61: 'качество',
#  62: 'год',
#  63: 'часть',
#  64: 'внесение',
#  65: 'составлять',
#  66: '5',
#  67: 'рубль',
#  68: 'такой',
#  69: 'установить',
#  70: 'федерация',
#  71: 'сторона',
#  72: 'действие',
#  73: 'реквизит',
#  74: 'требоваться',
#  75: 'заключение',
#  76: 'участие',
#  77: 'банк',
#  78: 'банковский',
#  79: 'система',
#  80: 'лицо',
#  81: 'муниципальный',
#  82: 'документ',
#  83: '2',
#  84: 'день',
#  85: 'проект',
#  86: 'условие',
#  87: 'запрос',
#  88: 'менее',
#  89: 'соответствовать',
#  90: 'учреждение',
#  91: 'исполнитель',
#  92: 'контрактный',
#  93: 'предусмотренный',
#  94: '2022',
#  95: 'сумма',
#  96: '3',
#  97: 'объект',
#  98: 'дата',
#  99: 'определяться',
#  100: 'область',
#  101: 'организация',
#  102: 'бик',
#  103: 'приложение',
#  104: 'превышать',
#  105: 'ст',
#  106: 'нужда',
#  107: 'общий',
#  108: 'законодательство',
#  109: 'предоставляться',
#  110: '45',
#  111: 'установленный',
#  112: 'предоставить',
#  113: 'результат',
#  114: 'котировка',
#  115: 'пункт',
#  116: 'самостоятельно',
#  117: 'положение',
#  118: 'расчётный',
#  119: 'процент',
#  120: 'обеспечиваться',
#  121: 'месяц',
#  122: 'вид',
#  123: 'являться',
#  124: 'число',
#  125: 'м.п',
#  126: 'осуществление',
#  127: '96',
#  128: '___',
#  129: 'сфера',
#  130: 'платёжный',
#  131: 'предложение',
#  132: 'основание',
#  133: 'лицевой',
#  134: 'раздел',
#  135: 'пять',
#  136: 'вправе',
#  137: 'адрес',
#  138: 'операция',
#  139: 'казначейский',
#  140: 'выполнение',
#  141: '4',
#  142: '10',
#  143: 'штраф',
#  144: 'учёт',
#  145: 'кредитный',
#  146: 'учитываться',
#  147: 'поступать',
#  148: 'бюджетный',
#  149: 'аванс',
#  150: 'корреспондентский',
#  151: 'также',
#  152: 'наличие',
#  153: 'устанавливаться',
#  154: 'г',
#  155: 'определение',
#  156: 'изменение',
#  157: 'далее',
#  158: 'отказ',
#  159: 'именовать',
#  160: '05.04.2013',
#  161: 'утверждать',
#  162: '0.00',
#  163: 'предоставлять',
#  164: 'течение',
#  165: 'сопровождение',
#  166: 'код',
#  167: '30',
#  168: 'дополнительный',
#  169: ']',
#  170: 'подпись',
#  171: 'победитель',
#  172: 'выдать',
#  173: 'действовать',
#  174: 'ч',
#  175: 'единица',
#  176: 'ненадлежащий',
#  177: 'путём',
#  178: 'ограничение',
#  179: 'директор',
#  180: 'предложить',
#  181: 'право',
#  182: 'копейка',
#  183: 'республика',
#  184: 'дальнейший',
#  185: 'один',
#  186: 'технический',
#  187: 'неустойка',
#  188: 'мочь',
#  189: 'россия',
#  190: 'предмет',
#  191: '[',
#  192: 'пеня',
#  193: '95',
#  194: 'следующий',
#  195: 'исключение',
#  196: 'акт',
#  197: 'подача',
#  198: '6',
#  199: 'односторонний',
#  200: 'подписание',
#  201: 'обеспечить',
#  202: 'оплата',
#  203: 'место',
#  204: 'платёж',
#  205: 'осуществляться',
#  206: 'оборудование',
#  207: '37',
#  208: 'ао',
#  209: 'характеристика',
#  210: '0',
#  211: 'руб',
#  212: '1.',
#  213: 'оказание',
#  214: 'получатель',
#  215: 'либо',
#  216: 'решение',
#  217: 'закупочный',
#  218: 'инна',
#  219: 'субъект',
#  220: 'отделение',
#  221: 'указать',
#  222: 'тысяча',
#  223: 'обоснование',
#  224: 'производитель',
#  225: 'иной',
#  226: 'сентябрь',
#  227: 'окончание',
#  228: 'гарант',
#  229: 'отдельный',
#  230: 'двадцать',
#  231: 'город',
#  232: 'перечисление',
#  233: 'допуск',
#  234: 'неисполнение',
#  235: 'подтверждать',
#  236: '__________',
#  237: 'малое',
#  238: 'кпп',
#  239: 'обслуживание',
#  240: 'возврат',
#  241: 'перечень',
#  242: 'правительство',
#  243: 'россии//уфк',
#  244: 'содержание',
#  245: 'ндс',
#  246: 'заключить',
#  247: 'ул',
#  248: '____',
#  249: 'рабочий',
#  250: 'информационный',
#  251: '__',
#  252: 'предпринимательство',
#  253: 'приёмка',
#  254: '7',
#  255: 'уплата',
#  256: 'казённый',
#  257: '<',
#  258: '20__',
#  259: 'свой',
#  260: '>',
#  261: '________',
#  262: 'площадка',
#  263: 'единый',
#  264: 'москва',
#  265: 'описание',
#  266: 'n',
#  267: '№44-фз',
#  268: 'рф',
#  269: 'открытый',
#  270: 'объём',
#  271: 'выполнить',
#  272: 'среднее',
#  273: '25',
#  274: 'протокол',
#  275: 'обязать',
#  276: '______________',
#  277: 'городской',
#  278: 'применяться',
#  279: 'отсутствовать',
#  280: 'момент',
#  281: 'идентификационный',
#  282: 'безотзывный',
#  283: 'центр',
#  284: 'автономный',
#  285: 'район',
#  286: 'стоимость',
#  287: 'состав',
#  288: 'отношение',
#  289: '8',
#  290: 'время',
#  291: 'постановление',
#  292: 'расторжение',
#  293: 'филиал',
#  294: 'п',
#  295: 'юридический',
#  296: 'здравоохранение',
#  297: 'этап',
#  298: 'процедура',
#  299: 'выплата',
#  300: 'медицинский',
#  301: 'край',
#  302: 'конкурс',
#  303: 'десять',
#  304: '8.1.',
#  305: 'подписать',
#  306: 'цель',
#  307: '00',
#  308: 'предприятие',
#  309: 'конкурентный',
#  310: 'иностранный',
#  311: 'гу',
#  312: 'применение',
#  313: 'недостаток',
#  314: 'связь',
#  315: 'поздний',
#  316: 'назначение',
#  317: 'ремонт',
#  318: '20',
#  319: 'установление',
#  320: '8.2.',
#  321: 'количество',
#  322: 'получение',
#  323: '12',
#  324: 'управление',
#  325: 'представить',
#  326: 'измерение',
#  327: 'расчёт',
#  328: 'обеспечивать',
#  329: 'ниже',
#  330: '________________',
#  331: 'раз',
#  332: '_____________',
#  333: 'московский',
#  334: 'общество',
#  335: 'выбор',
#  336: 'согласно',
#  337: 'уфк',
#  338: 'унитарный',
#  339: 'сведение',
#  340: 'больница',
#  341: 'запрет',
#  342: 'нмц',
#  343: 'поставить',
#  344: 'позиция',
#  345: 'обстоятельство',
#  346: 'содержать',
#  347: 'возмещение',
#  348: '24',
#  349: '14',
#  350: 'б',
#  351: 'питание',
#  352: 'полтора',
#  353: 'новый',
#  354: '/',
#  355: 'указание',
#  356: 'эксплуатация',
#  357: 'пао',
#  358: 'продукт',
#  359: 'прикрепить',
#  360: 'соответствующий',
#  361: 'ранее',
#  362: 'возможность',
#  363: 'мера',
#  364: 'внести',
#  365: '16',
#  366: '___________',
#  367: 'итого',
#  368: 'надлежащий',
#  369: 'л/с',
#  370: '_______',
#  371: 'реестр',
#  372: 'расход',
#  373: 'соблюдение',
#  374: 'имя',
#  375: '15',
#  376: 'значение',
#  377: 'комиссия',
#  378: 'обязанность',
#  379: 'итог',
#  380: 'указываться',
#  381: '_____________________',
#  382: 'утвердить',
#  383: 'содержаться',
#  384: 'начислить',
#  385: '44',
#  386: '2023',
#  387: 'округ',
#  388: 'письменный',
#  389: 'валюта',
#  390: 'включая',
#  391: 'убыток',
#  392: 'карта',
#  393: 'лот',
#  394: 'финансовый',
#  395: 'использование',
#  396: '13',
#  397: 'самарский',
#  398: 'оценка',
#  399: 'материал',
#  400: '2024',
#  401: 'принятие',
#  402: 'саха',
#  403: 'снизить',
#  404: 'покупатель',
#  405: 'санкт-петербург',
#  406: 'генеральный',
#  407: '_____',
#  408: 'он',
#  409: 'выполнять',
#  410: 'тридцать',
#  411: 'исполнить',
#  412: 'подлежать',
#  413: 'изменить',
#  414: 'файл',
#  415: 'правило',
#  416: 'другой',
#  417: 'задание',
#  418: 'рассмотрение',
#  419: 'прилагать',
#  420: 'включить',
#  421: 'принять',
#  422: 'государство',
#  423: 'устранение',
#  424: 'три',
#  425: '9',
#  426: 'календарный',
#  427: 'дефект',
#  428: '_______________',
#  429: 'данный',
#  430: '____________',
#  431: '___________________',
#  432: 'приказ',
#  433: 'смотреть',
#  434: '31',
#  435: 'р/с',
#  436: 'соглашение',
#  437: 'помещение',
#  438: '@',
#  439: 'гражданский',
#  440: '2.',
#  441: 'специальный',
#  442: 'ход',
#  443: 'кодекс',
#  444: 'администрация',
#  445: '_________',
#  446: 'подпункт',
#  447: 'акционерный',
#  448: 'происхождение',
#  449: 'основный',
#  450: 'поставлять',
#  451: '*',
#  452: 'строительство',
#  453: '______',
#  454: 'изделие',
#  455: 'заместитель',
#  456: 'оказывать',
#  457: 'размещение',
#  458: 'иметь',
#  459: 'начальник',
#  460: 'почтовый',
#  461: 'быть',
#  462: 'каждый',
#  463: 'врач',
#  464: 'нарушение',
#  465: 'оформление',
#  466: 'нахождение',
#  467: 'почта',
#  468: 'финансы',
#  469: 'преимущество',
#  470: '0,5',
#  471: 'сила',
#  472: 'полный',
#  473: 'министерство',
#  474: 'продукция',
#  475: '8.3.',
#  476: '____________________',
#  477: 'два',
#  478: '22',
#  479: '2013',
#  480: '000000000',
#  481: 'отсутствие',
#  482: 'главный',
#  483: 'якутия',
#  484: 'устанавливать',
#  485: '6.1.',
#  486: 'потребовать',
#  487: '00000000000000000000',
#  488: 'должность',
#  489: 'особенность',
#  490: 'образование',
#  491: 'облагаться',
#  492: '11',
#  493: 'дать',
#  494: 'бенефициар',
#  495: 'согласовать',
#  496: 'апрель',
#  497: 'общеобразовательный',
#  498: 'осуществлять',
#  499: 'капитальный',
#  500: '1.1.',
#  501: 'ценовый',
#  502: 'низкий',
#  503: 'антидемпинговый',
#  504: 'жилой',
#  505: '42',
#  506: 'направить',
#  507: 'руководитель',
#  508: 'производиться',
#  509: '�',
#  510: 'взамен',
#  511: '223-фз',
#  512: 'замена',
#  513: '_________________',
#  514: 'период',
#  515: '№____',
#  516: '6.2',
#  517: 'понести',
#  518: 'физический',
#  519: '6.1',
#  520: 'служба',
#  521: '0,50',
#  522: '__________________',
#  523: 'контактный',
#  524: 'тип',
#  525: 'клинический',
#  526: 'ущерб',
#  527: 'происходить',
#  528: 'аномально',
#  529: 'центральный',
#  530: 'сеть',
#  531: 'критерий',
#  532: 'd0',
#  533: 'кредит',
#  534: 'выдача',
#  535: 'подлежащее',
#  536: 'лекарственный',
#  537: 'препарат',
#  538: 'обязываться',
#  539: 'уполномоченный',
#  540: 'начало',
#  541: 'п.16',
#  542: 'уведомление',
#  543: 'п/п',
#  544: 'поручение',
#  545: '0,00',
#  546: 'ответственность',
#  547: 'подведение',
#  548: 'любой',
#  549: 'признаваться',
#  550: '2025',
#  551: 'телефон',
#  552: 'фонд',
#  553: 'орган',
#  554: 'приоритет',
#  555: 'кбк',
#  556: '9.2.',
#  557: '1,5',
#  558: 'оказать',
#  559: 'к/с',
#  560: 'еис',
#  561: '3.',
#  562: 'направление',
#  563: 'факт',
#  564: 'нмцк',
#  565: '№1',
#  566: 'уклониться',
#  567: 'заключать',
#  568: 'торговый',
#  569: 'территория',
#  570: 'уменьшить',
#  571: 'разъяснение',
#  572: 'россеть',
#  573: 'собственный',
#  574: 'использовать',
#  575: 'увеличить',
#  576: 'окпд2',
#  577: 'разместить',
#  578: 'причинить',
#  579: 'огрн',
#  580: 'семь',
#  581: '18',
#  582: 'освобождаться',
#  583: 'млн',
#  584: 'освобождать',
#  585: '50',
#  586: 'фамилия',
#  587: 'эквивалентный',
#  588: 'контракта.',
#  589: 'обязательный',
#  590: 'развитие',
#  591: '17',
#  592: 'сайт',
#  593: 'авансовый',
#  594: 'гбуз',
#  595: 'октмый',
#  596: 'footnoteref:16',
#  597: 'финансирование',
#  598: '5.00',
#  599: 'образовательный',
#  600: 'вместе',
#  601: 'ктереть',
#  602: 'уклонение',
#  603: 'снижение',
#  604: 'окончательный',
#  605: '2022г',
#  606: '000',
#  607: '21',
#  608: 'возвращаться',
#  609: 'минфин',
#  610: '№2',
#  611: 'икз',
#  612: 'дом',
#  613: 'нижеследующий',
#  614: 'претензия',
#  615: 'обусловить',
#  616: 'единственный',
#  617: 'представляться',
#  618: 'главное',
#  619: 'уплатить',
#  620: 'последний',
#  621: 'оператор',
#  622: 'первоначально',
#  623: 'первый',
#  624: 'фактически',
#  625: 'нести',
#  626: '·',
#  627: 'официальный',
#  628: 'муп',
#  629: '9.3.',
#  630: 'областной',
#  631: '_______________________',
#  632: 'второй',
#  633: 'сто',
#  634: 'оформить',
#  635: 'сократить',
#  636: '8.',
#  637: 'связанный',
#  638: 'и/ить',
#  639: 'непосредственно',
#  640: 'отвечать',
#  641: 'гауз',
#  642: '1.1',
#  643: 'последующий',
#  644: 'ввод',
#  645: '26',
#  646: 'распространяться',
#  647: 'устав',
#  648: 'пятьдесят',
#  649: 'проводиться',
#  650: 'принципал',
#  651: 'фгуп',
#  652: 'атомный',
#  653: 'считаться',
#  654: 'определённый',
#  655: 'ii',
#  656: 'viii',
#  657: 'новосибирский',
#  658: 'копа',
#  659: 'отбор',
#  660: 'приобретение',
#  661: 'социальный',
#  662: '126н',
#  663: '04.06.2018',
#  664: 'июль',
#  665: 'концерн',
#  666: 'башкортостан',
#  667: 'i.',
#  668: 'добросовестность',
#  669: 'примечание',
#  670: 'департамент',
#  671: 'мп',
#  672: 'фио',
#  673: 'субподрядчик',
#  674: 'этп',
#  675: 'красноярский',
#  676: 'отчётный',
#  677: 'председатель',
#  678: '__________________________',
#  679: '19',
#  680: 'госкорпорация',
#  681: 'миллион',
#  682: '9.1.',
#  683: '№3',
#  684: 'детский',
#  685: '100',
#  686: 'инструкция',
#  687: 'третий',
#  688: 'спецификация',
#  689: 'показатель',
#  690: 'деятельность',
#  691: 'производство',
#  692: 'шесть',
#  693: 'фз',
#  694: 'просрочка',
#  695: 'вариант',
#  696: 'ханты-мансийский',
#  697: '4.',
#  698: 'правовой',
#  699: 'р',
#  700: 'так',
#  701: 'привести',
#  702: 'краснодарский',
#  703: 'ограниченный',
#  704: 'необходимый',
#  705: 'допускаться',
#  706: 'безопасность',
#  707: 'невозможность',
#  708: 'вследствие',
#  709: 'непреодолимый',
#  710: '925',
#  711: 'шестьдесят',
#  712: 'page',
#  713: 'необходимо',
#  714: 'подтверждение',
#  715: 'предварительный',
#  716: 'ленинградский',
#  717: '______________________',
#  718: 'промышленный',
#  719: 'якутск',
#  720: 'автомобильный',
#  721: 'усиленный',
#  722: 'итоговый',
#  723: 'уменьшение',
#  724: '10.00',
#  725: 'школа',
#  726: '10.',
#  727: 'регламент',
#  728: 'челябинск',
#  729: '_________________________',
#  730: 'подать',
#  731: 'конкурсный',
#  732: 'росатом',
#  733: 'окпо',
#  734: 'страна',
#  735: '244',
#  736: 'причина',
#  737: '23',
#  738: 'краевой',
#  739: 'организатор',
#  740: 'допускать',
#  741: 'подтверждаться',
#  742: 'функциональный',
#  743: 'здание',
#  744: 'обучение',
#  745: 'краткий',
#  746: 'вина',
#  747: 'свердловский',
#  748: 'специалист',
#  749: 'признание',
#  750: 'заполнение',
#  751: '60',
#  752: 'гбу',
#  753: 'краснодар',
#  754: 'раздельный',
#  755: 'тело',
#  756: 'сверка',
#  757: '7.',
#  758: '7.1.',
#  759: '7.14.',
#  760: 'экономический',
#  761: 'ф.и.ый',
#  762: 'станция',
#  763: 'включаться',
#  764: 'четыре',
#  765: 'сопоставление',
#  766: 'северо-западный',
#  767: 'передача',
#  768: 'посредством',
#  769: '7.2.',
#  770: 'институт',
#  771: 'выявить',
#  772: 'гарантировать',
#  773: 'национальный',
#  774: 'iii',
#  775: 'коммерческий',
#  776: 'нмцд',
#  777: 'гау',
#  778: 'квартира',
#  779: '1000',
#  780: 'отделение-нб',
#  781: '33',
#  782: 'получить',
#  783: 'разногласие',
#  784: 'плюс',
#  785: 'доверенность',
#  786: 'росэнергоатом',
#  787: 'печать',
#  788: 'одновременно',
#  789: '________________________',
#  790: 'включать',
#  791: '9.',
#  792: 'представлять',
#  793: 'отдел',
#  794: 'монтаж',
#  795: '00000000000000000510',
#  796: 'реестровый',
#  797: '№4',
#  798: '1.2.',
#  799: 'http',
#  800: '2.1.',
#  801: 'ооо',
#  802: '20___',
#  803: 'аукционный',
#  804: '08.11.2013',
#  805: 'гражданско-правовой',
#  806: 'фгб',
#  807: 'составить',
#  808: 'правопреемство',
#  809: 'ответственный',
#  810: 'договорный',
#  811: 'направлять',
#  812: 'перечисленный',
#  813: 'н',
#  814: 'югра',
#  815: 'признать',
#  816: 'обеспечительный',
#  817: 'экспертиза',
#  818: 'высокий',
#  819: 'инн/кпп',
#  820: 'восемьдесят',
#  821: 'калининградский',
#  822: 'девять',
#  823: 'комитет',
#  824: 'ребёнок',
#  825: 'нижний',
#  826: 'нормативно-правовой',
#  827: 'с.',
#  828: 'налоговый',
#  829: 'весь',
#  830: 'истечение',
#  831: 'гуп',
#  832: 'мособлгаз',
#  833: 'расходный',
#  834: 'привлечение',
#  835: 'рамка',
#  836: 'списание',
#  837: '29',
#  838: 'информационно-телекоммуникационный',
#  839: 'устранить',
#  840: 'улица',
#  841: 'интернет',
#  842: 'заказ',
#  843: 'инициал',
#  844: '014030106',
#  845: 'инвалид',
#  846: 'новгород',
#  847: '5,00',
#  848: 'произойти',
#  849: 'евразийский',
#  850: 'член',
#  851: '//',
#  852: 'девяносто',
#  853: 'судебный',
#  854: 'сорок',
#  855: 'факс',
#  856: 'квалифицировать',
#  857: 'хозяйство',
#  858: 'данные',
#  859: 'кв',
#  860: '2011',
#  861: 'изготовитель',
#  862: 'красноярск',
#  863: 'пятнадцать',
#  864: 'цфо//уфк',
#  865: 'представитель',
#  866: 'россии//',
#  867: '10.1.',
#  868: '7.15.',
#  869: 'технологический',
#  870: '7.16.',
#  871: '06',
#  872: 'проектный',
#  873: 'пятьсот',
#  874: 'строительно-монтажный',
#  875: 'сбербанк',
#  876: 'лицензия',
#  877: 'осуществить',
#  878: 'несколько',
#  879: 'нижегородский',
#  880: 'полностью',
#  881: 'отзыв',
#  882: 'установка',
#  883: 'корпорация',
#  884: 'триста',
#  885: 'необходимость',
#  886: '11.',
#  887: 'восемь',
#  888: 'предъявлять',
#  889: '7.17.',
#  890: 'поручительство',
#  891: 'мсп',
#  892: 'совместно',
#  893: '7.3.',
#  894: 'инженерный',
#  895: 'и.о',
#  896: 'текст',
#  897: 'оригинал',
#  898: 'залог',
#  899: 'продавец',
#  900: '7.2',
#  901: 'средний',
#  902: 'формирование',
#  903: '6.',
#  904: 'двести',
#  905: 'поступить',
#  906: 'квалификационный',
#  907: 'спб',
#  908: 'знак',
#  909: '9.4.',
#  910: 'помощь',
#  911: '000,00',
#  912: 'ед',
#  913: 'вносить',
#  914: 'налог',
#  915: 'дорога',
#  916: '8.4.',
#  917: 'четыреста',
#  918: 'восемьсот',
#  919: '40102810945370000005',
#  920: '5.',
#  921: '34',
#  922: 'подавать',
#  923: '+7',
#  924: 'соответственно',
#  925: 'калининград',
#  926: 'арбитражный',
#  927: 'непредоставление',
#  928: '109',
#  929: '110',
#  930: 'соисполнитель',
#  931: 'подраздел',
#  932: 'статус',
#  933: 'штука',
#  934: '________________________________',
#  935: 'включительно',
#  936: '1005',
#  937: 'перечисляться',
#  938: 'продлеваться',
#  939: 'устройство',
#  940: 'липецкий',
#  941: 'суд',
#  942: '21.',
#  943: 'бакалея',
#  944: 'прилагаться',
#  945: '18.07.2011',
#  946: 'относительно',
#  947: 'южный',
#  948: 'ответ',
#  949: 'алтайский',
#  950: 'семьдесят',
#  951: 'индивидуальный',
#  952: 'кемерово',
#  953: 'исчисляться',
#  954: 'образец',
#  955: 'минздрав',
#  956: 'входящий',
#  957: '12.',
#  958: 'фгбоу',
#  959: '10.2.',
#  960: 'оформляться',
#  961: 'саратовский',
#  962: 'местный',
#  963: 'наступление',
#  964: 'тульский',
#  965: 'подряд',
#  966: 'р/сча',
#  967: 'авансирование',
#  968: 'ресурс',
#  969: 'распоряжение',
#  970: 'севастополь',
#  971: 'корпус',
#  972: 'согласование',
#  973: 'одновременный',
#  974: 'научно-исследовательский',
#  975: 'подготовка',
#  976: 'письмо',
#  977: '1.3.',
#  978: 'глава',
#  979: 'отребовать',
#  980: '144',
#  981: 'какой-либо',
#  982: 'сметный',
#  983: 'тепловой',
#  984: 'энергия',
#  985: '___________________________',
#  986: 'поликлиника',
#  987: 'поле',
#  988: '010349101',
#  989: 'м',
#  990: 'начисляться',
#  991: 'использоваться',
#  992: 'удовлетворение',
#  993: 'сочи',
#  994: 'комплекс',
#  995: '1.2',
#  996: 'начинать',
#  997: 'удержание',
#  998: '05',
#  999: 'среди',
#  1000: 'источник',
#  1001: 'л',
#  ...}

# %% [markdown]
# ## Преобразуем слова в коды

# %% [markdown]
# Функция для преобразования списка слов в список кодов

# %%
def text_to_sequence(txt, word_to_index):
    seq = []
    for word in txt:
        index = word_to_index.get(word, 1) # 1 означает неизвестное слово
        # Неизвестные слова не добавляем в выходную последовательность
        if index != 1:
            seq.append(index)
    return seq

# %%
txt = banks['texts'][0]

# %%
txt
# Out:
# ['извещение',
#  'проведение',
#  'открытый',
#  'конкурс',
#  'электронный',
#  'форма',
#  'закупка',
#  '№0328300032822000806',
#  'общий',
#  'информация',
#  'номер',
#  'извещение',
#  '0328300032822000806',
#  'наименование',
#  'объект',
#  'закупка',
#  'поставка',
#  'продукт',
#  'питание',
#  'способ',
#  'определение',
#  'поставщик',
#  'подрядчик',
#  'исполнитель',
#  'открытый',
#  'конкурс',
#  'бль',
#  'порядок',
#  'внесение',
#  'денежный',
#  'средство',
#  'качество',
#  'обеспечение',
#  'заявка',
#  'участие',
#  'закупка',
#  'также',
#  'условие',
#  'гарантия',
#  'обеспечение',
#  'заявка',
#  'участие',
#  'закупка',
#  'предоставляться',
#  'участник',
#  'закупка',
#  'вид',
#  'денежный',
#  'средство',
#  'независимый',
#  'гарантия',
#  'предусмотреть',
#  'ст',
#  '45',
#  'федеральный',
#  'закон',
#  '№',
#  '44-фз',
#  'выбор',
#  'способ',
#  'обеспечение',
#  'осуществляться',
#  'участник',
#  'закупка',
#  'самостоятельно',
#  'срок',
#  'действие',
#  'независимый',
#  'гарантия',
#  'должный',
#  'составлять',
#  'менее',
#  'месяц',
#  'дата',
#  'окончание',
#  'срок',
#  'подача',
#  'заявка',
#  'обеспечение',
#  'заявка',
#  'участие',
#  'закупка',
#  'предоставляться',
#  'соответствие',
#  'ч',
#  '5',
#  'ст',
#  '44',
#  'федеральный',
#  'закон',
#  '№',
#  '44-фз',
#  'условие',
#  'независимый',
#  'гарантия',
#  'соответствие',
#  'ст',
#  '45',
#  'федеральный',
#  'закон',
#  '№',
#  '44-фз',
#  'реквизит',
#  'счёт',
#  'соответствие',
#  'п.16',
#  'ч',
#  '1',
#  'ст',
#  '42',
#  'закон',
#  '№',
#  '44-фз',
#  '``',
#  'номер',
#  'расчётный',
#  'счёт',
#  "''",
#  '00000000000000000000',
#  '``',
#  'номер',
#  'лицевой',
#  'счёт',
#  "''",
#  'смотреть',
#  'прилагать',
#  'документ',
#  '``',
#  'бик',
#  "''",
#  '000000000',
#  '``',
#  'наименование',
#  'кредитный',
#  'организация',
#  "''",
#  '``',
#  'номер',
#  'корреспондентский',
#  'счёт',
#  "''",
#  'обеспечение',
#  'исполнение',
#  'контракт',
#  'требоваться',
#  'обеспечение',
#  'исполнение',
#  'контракт',
#  'размер',
#  'обеспечение',
#  'исполнение',
#  'контракт',
#  '6593.25',
#  'российский',
#  'рубль',
#  'порядок',
#  'обеспечение',
#  'исполнение',
#  'контракт',
#  'требование',
#  'обеспечение',
#  'исполнение',
#  'контракт',
#  'гарантийный',
#  'обязательство',
#  'мочь',
#  'обеспечиваться',
#  'предоставление',
#  'независимый',
#  'гарантия',
#  'соответствовать',
#  'требование',
#  'ст',
#  '45',
#  'федеральный',
#  'закон',
#  '№',
#  '44-фз',
#  'внесение',
#  'денежный',
#  'средство',
#  'указанный',
#  'заказчик',
#  'счёт',
#  'который',
#  'соответствие',
#  'законодательство',
#  'российский',
#  'федерация',
#  'учитываться',
#  'операция',
#  'средство',
#  'поступать',
#  'заказчик',
#  'способ',
#  'обеспечение',
#  'исполнение',
#  'контракт',
#  'гарантийный',
#  'обязательство',
#  'срок',
#  'действие',
#  'независимый',
#  'гарантия',
#  'определяться',
#  'соответствие',
#  'требование',
#  'федеральный',
#  'закон',
#  '№',
#  '44-фз',
#  'участник',
#  'закупка',
#  'который',
#  'заключаться',
#  'контракт',
#  'самостоятельно',
#  'срок',
#  'действие',
#  'независимый',
#  'гарантия',
#  'должный',
#  'превышать',
#  'предусмотренный',
#  'контракт',
#  'срок',
#  'исполнение',
#  'обязательство',
#  'который',
#  'должный',
#  'обеспечить',
#  'независимый',
#  'гарантия',
#  'менее',
#  'месяц',
#  'число',
#  'случай',
#  'изменение',
#  'соответствие',
#  'ст',
#  '95',
#  'федеральный',
#  'закон',
#  '№',
#  '44-фз',
#  'порядок',
#  'предоставление',
#  'требование',
#  'информация',
#  'документ',
#  'подтверждать',
#  'соответствие',
#  'участник',
#  'закупка',
#  'дополнительный',
#  'требование',
#  '1',
#  'исполнить',
#  'договор',
#  '2',
#  'акт',
#  'приёмка',
#  'оказать',
#  'услуга',
#  'поставить',
#  'товар',
#  'подтверждать',
#  'цена',
#  'оказать',
#  'услуга',
#  'поставить',
#  'товар',
#  '4']

# %%
seq = text_to_sequence(txt, word_to_index)

# %%
seq
# Out:
# [33,
#  52,
#  269,
#  302,
#  29,
#  48,
#  6,
#  7515,
#  107,
#  46,
#  34,
#  33,
#  7516,
#  53,
#  97,
#  6,
#  57,
#  358,
#  351,
#  59,
#  155,
#  25,
#  60,
#  91,
#  269,
#  302,
#  4952,
#  45,
#  64,
#  38,
#  26,
#  61,
#  2,
#  31,
#  76,
#  6,
#  151,
#  86,
#  10,
#  2,
#  31,
#  76,
#  6,
#  109,
#  17,
#  6,
#  122,
#  38,
#  26,
#  24,
#  10,
#  44,
#  105,
#  110,
#  37,
#  21,
#  12,
#  41,
#  335,
#  59,
#  2,
#  205,
#  17,
#  6,
#  116,
#  16,
#  72,
#  24,
#  10,
#  47,
#  65,
#  88,
#  121,
#  98,
#  227,
#  16,
#  197,
#  31,
#  2,
#  31,
#  76,
#  6,
#  109,
#  20,
#  174,
#  66,
#  105,
#  385,
#  37,
#  21,
#  12,
#  41,
#  86,
#  24,
#  10,
#  20,
#  105,
#  110,
#  37,
#  21,
#  12,
#  41,
#  73,
#  13,
#  20,
#  541,
#  174,
#  40,
#  105,
#  505,
#  21,
#  12,
#  41,
#  22,
#  34,
#  118,
#  13,
#  23,
#  487,
#  22,
#  34,
#  133,
#  13,
#  23,
#  433,
#  419,
#  82,
#  22,
#  102,
#  23,
#  480,
#  22,
#  53,
#  145,
#  101,
#  23,
#  22,
#  34,
#  150,
#  13,
#  23,
#  2,
#  4,
#  3,
#  74,
#  2,
#  4,
#  3,
#  14,
#  2,
#  4,
#  3,
#  7517,
#  43,
#  67,
#  45,
#  2,
#  4,
#  3,
#  9,
#  2,
#  4,
#  3,
#  11,
#  8,
#  188,
#  120,
#  28,
#  24,
#  10,
#  89,
#  9,
#  105,
#  110,
#  37,
#  21,
#  12,
#  41,
#  64,
#  38,
#  26,
#  55,
#  7,
#  13,
#  18,
#  20,
#  108,
#  43,
#  70,
#  146,
#  138,
#  26,
#  147,
#  7,
#  59,
#  2,
#  4,
#  3,
#  11,
#  8,
#  16,
#  72,
#  24,
#  10,
#  99,
#  20,
#  9,
#  37,
#  21,
#  12,
#  41,
#  17,
#  6,
#  18,
#  56,
#  3,
#  116,
#  16,
#  72,
#  24,
#  10,
#  47,
#  104,
#  93,
#  3,
#  16,
#  4,
#  8,
#  18,
#  47,
#  201,
#  24,
#  10,
#  88,
#  121,
#  124,
#  30,
#  156,
#  20,
#  105,
#  193,
#  37,
#  21,
#  12,
#  41,
#  45,
#  28,
#  9,
#  46,
#  82,
#  235,
#  20,
#  17,
#  6,
#  168,
#  9,
#  40,
#  411,
#  5,
#  83,
#  196,
#  253,
#  558,
#  32,
#  343,
#  15,
#  235,
#  19,
#  558,
#  32,
#  343,
#  15,
#  141]

# %%
index_to_word[241]
# Out:
# 'перечень'

# %%
seq = [word_to_index.get(word, 1) for word in txt]

# %%
seq
# Out:
# [33,
#  52,
#  269,
#  302,
#  29,
#  48,
#  6,
#  7515,
#  107,
#  46,
#  34,
#  33,
#  7516,
#  53,
#  97,
#  6,
#  57,
#  358,
#  351,
#  59,
#  155,
#  25,
#  60,
#  91,
#  269,
#  302,
#  4952,
#  45,
#  64,
#  38,
#  26,
#  61,
#  2,
#  31,
#  76,
#  6,
#  151,
#  86,
#  10,
#  2,
#  31,
#  76,
#  6,
#  109,
#  17,
#  6,
#  122,
#  38,
#  26,
#  24,
#  10,
#  44,
#  105,
#  110,
#  37,
#  21,
#  12,
#  41,
#  335,
#  59,
#  2,
#  205,
#  17,
#  6,
#  116,
#  16,
#  72,
#  24,
#  10,
#  47,
#  65,
#  88,
#  121,
#  98,
#  227,
#  16,
#  197,
#  31,
#  2,
#  31,
#  76,
#  6,
#  109,
#  20,
#  174,
#  66,
#  105,
#  385,
#  37,
#  21,
#  12,
#  41,
#  86,
#  24,
#  10,
#  20,
#  105,
#  110,
#  37,
#  21,
#  12,
#  41,
#  73,
#  13,
#  20,
#  541,
#  174,
#  40,
#  105,
#  505,
#  21,
#  12,
#  41,
#  22,
#  34,
#  118,
#  13,
#  23,
#  487,
#  22,
#  34,
#  133,
#  13,
#  23,
#  433,
#  419,
#  82,
#  22,
#  102,
#  23,
#  480,
#  22,
#  53,
#  145,
#  101,
#  23,
#  22,
#  34,
#  150,
#  13,
#  23,
#  2,
#  4,
#  3,
#  74,
#  2,
#  4,
#  3,
#  14,
#  2,
#  4,
#  3,
#  7517,
#  43,
#  67,
#  45,
#  2,
#  4,
#  3,
#  9,
#  2,
#  4,
#  3,
#  11,
#  8,
#  188,
#  120,
#  28,
#  24,
#  10,
#  89,
#  9,
#  105,
#  110,
#  37,
#  21,
#  12,
#  41,
#  64,
#  38,
#  26,
#  55,
#  7,
#  13,
#  18,
#  20,
#  108,
#  43,
#  70,
#  146,
#  138,
#  26,
#  147,
#  7,
#  59,
#  2,
#  4,
#  3,
#  11,
#  8,
#  16,
#  72,
#  24,
#  10,
#  99,
#  20,
#  9,
#  37,
#  21,
#  12,
#  41,
#  17,
#  6,
#  18,
#  56,
#  3,
#  116,
#  16,
#  72,
#  24,
#  10,
#  47,
#  104,
#  93,
#  3,
#  16,
#  4,
#  8,
#  18,
#  47,
#  201,
#  24,
#  10,
#  88,
#  121,
#  124,
#  30,
#  156,
#  20,
#  105,
#  193,
#  37,
#  21,
#  12,
#  41,
#  45,
#  28,
#  9,
#  46,
#  82,
#  235,
#  20,
#  17,
#  6,
#  168,
#  9,
#  40,
#  411,
#  5,
#  83,
#  196,
#  253,
#  558,
#  32,
#  343,
#  15,
#  235,
#  19,
#  558,
#  32,
#  343,
#  15,
#  141]

# %% [markdown]
# Преобразуем все тексты в последовательность кодов слов

# %%
banks['Sequences'] = banks.apply(lambda row: text_to_sequence(row['texts'], word_to_index), axis=1)

# %%
banks
# Out:
#              id                                               text  \
# 0     809436509  Извещение о проведении открытого конкурса в эл...
# 1     854885310  ТРЕБОВАНИЯ К СОДЕРЖАНИЮ ЗАЯВКИ участника запро...
# 2       4382157  Извещение о проведении электронного аукциона д...
# 3     184555082  Извещение о проведении электронного аукциона д...
# 4     211645258  Извещение о проведении электронного аукциона д...
# ...         ...                                                ...
# 1794  938335285  «УТВЕРЖДАЮ» Директор МУП "ПКП и ОРТ" _________...
# 1795  214609521  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ УНИТАРНОЕ ПРЕДПРИЯ...
# 1796   94811748  ДОГОВОР ПОДРЯДА № _____ «___»___________20____...
# 1797  903507299  ДОКУМЕНТАЦИЯ О ЗАКУПКЕ ЗАПРОС ПРЕДЛОЖЕНИЙ В ЭЛ...
# 1798  926039184  Государственная корпорацИя по атомной энергии ...
#
#                                      label  \
# 0         обеспечение исполнения контракта
# 1         обеспечение исполнения контракта
# 2         обеспечение исполнения контракта
# 3         обеспечение исполнения контракта
# 4         обеспечение исполнения контракта
# ...                                    ...
# 1794  обеспечение гарантийных обязательств
# 1795  обеспечение гарантийных обязательств
# 1796  обеспечение гарантийных обязательств
# 1797  обеспечение гарантийных обязательств
# 1798  обеспечение гарантийных обязательств
#
#                                          extracted_part  \
# 0     {'text': ['Размер обеспечения исполнения контр...
# 1     {'text': ['Поставщик должен предоставить обесп...
# 2     {'text': ['Размер обеспечения исполнения контр...
# 3     {'text': ['Размер обеспечения исполнения контр...
# 4     {'text': ['Размер обеспечения исполнения контр...
# ...                                                 ...
# 1794  {'text': ['Заказчиком установлено требование о...
# 1795  {'text': [''], 'answer_start': [0], 'answer_en...
# 1796  {'text': [''], 'answer_start': [0], 'answer_en...
# 1797  {'text': [''], 'answer_start': [0], 'answer_en...
# 1798  {'text': [''], 'answer_start': [0], 'answer_en...
#
#                                                   texts  \
# 0     [извещение, проведение, открытый, конкурс, эле...
# 1     [требование, содержание, заявка, участник, зап...
# 2     [извещение, проведение, электронный, аукцион, ...
# 3     [извещение, проведение, электронный, аукцион, ...
# 4     [извещение, проведение, электронный, аукцион, ...
# ...                                                 ...
# 1794  [утверждать, директор, муп, ``, пкп, орт, '', ...
# 1795  [федеральный, государственный, унитарный, пред...
# 1796  [договор, подряд, №, _____, ___, ___________20...
# 1797  [документация, закупка, запрос, предложение, э...
# 1798  [государственный, корпорация, атомный, энергия...
#
#                                               Sequences
# 0     [33, 52, 269, 302, 29, 48, 6, 7515, 107, 46, 3...
# 1     [9, 244, 31, 17, 87, 114, 29, 48, 31, 76, 87, ...
# 2     [33, 52, 29, 54, 6, 7522, 107, 46, 34, 33, 752...
# 3     [33, 52, 29, 54, 6, 7534, 107, 46, 34, 33, 753...
# 4     [33, 52, 29, 54, 6, 7537, 107, 46, 34, 33, 753...
# ...                                                 ...
# 1794  [161, 179, 628, 22, 5997, 5998, 23, 1410, 2542...
# 1795  [37, 51, 338, 308, 1088, 1955, 4934, 161, 677,...
# 1796  [5, 965, 12, 407, 128, 7334, 357, 572, 1584, 1...
# 1797  [58, 6, 87, 131, 29, 48, 181, 75, 5, 213, 32, ...
# 1798  [51, 883, 652, 984, 732, 447, 334, 2901, 2609,...
#
# [1799 rows x 6 columns]

# %%
banks['text'][1]
# Out:
# 'ТРЕБОВАНИЯ К СОДЕРЖАНИЮ ЗАЯВКИ участника запроса котировок в электронной форме Заявка на участие в запросе котировок в электронной форме должна содержать следующие информацию и документы: 1) об участнике запроса котировок носят на банковский счет, открытый в банке, включенном в перечень, который утвержден распоряжением Правительства Российской Федерации от 13.07.2018 N 1451-р. Требования к банкам, договору специального счета, к порядку использования имеющегося у участника закупки банковского счета в качестве специального счета Правительство РФ установило в постановлении от 30.05.2018 №626. Независимая гарантия должна соответствовать требованиям статьи 45 Закона № 44-ФЗ Реквизиты счета, на котором в соответствии с законодательством Российской Федерации учитываются операции со средствами, поступающими заказчику: Наименование заказчика: Санкт-Петербургское государственное бюджетное учреждение здравоохранения «Городская поликлиника № 95» (СПб ГБУЗ ГП № 95) Реквизиты: ИНН 7817026947, КПП 781701001 Реквизиты банковского счета: Северо-Западное ГУ БАНКА РОССИИ//УФК по г.Санкт-Петербургу, г. Санкт-Петербург БИК 014030106, номер счета банка получателя 03224643400000007200, казначейский счет 40102810945370000005. Поставщик должен предоставить обеспечение исполнения контракта в размере 10 % от цены Контракта. В случае если обеспечение исполнения контракта предоставляется в виде передачи заказчику денежных средств, участник запроса котировок в электронной форме, с которым заключается контракт, перечисляет денежные средства на счет: СПб ГБУЗ ГП №95, ИНН 7817026947, КПП 781701001, Получатель платежа: Комитет финансов СПб ( СПб ГБУЗ ГП № 95, л/с 0531015) Реквизиты банковского счета: Северо-Западное ГУ БАНКА РОССИИ//УФК по г. Санкт-Петербургу, БИК 014030106, номер счета банка получателя 03224643400000007200, к/с 40102810945370000005 В поле 104 платежных документов указывается код бюджетной классификации, имеющий 20 знаков: «00000000000000003510». В платежном поручении в поле "Назначение платежа" указывается 510 (ВР) 0531015 Перечисление обеспечения контракта (предмет контракта и номер извещения об осуществлении закупки) НДС не обл. Денежные средства, внесенные в качестве обеспечения исполнения Контракта, в том числе части этих денежных средств в случае уменьшения размера обеспечения исполнения  Сведения, содержащиеся в котировочной заявке участника, не должны допускать двусмысленных толкований.'

# %%
banks['texts'][1]
# Out:
# ['требование',
#  'содержание',
#  'заявка',
#  'участник',
#  'запрос',
#  'котировка',
#  'электронный',
#  'форма',
#  'заявка',
#  'участие',
#  'запрос',
#  'котировка',
#  'электронный',
#  'форма',
#  'должный',
#  'содержать',
#  'следующий',
#  'информация',
#  'документ',
#  '1',
#  'участник',
#  'запрос',
#  'котировка',
#  'носить',
#  'банковский',
#  'счёт',
#  'открытый',
#  'банк',
#  'включить',
#  'перечень',
#  'который',
#  'утвердить',
#  'распоряжение',
#  'правительство',
#  'российский',
#  'федерация',
#  '13.07.2018',
#  'n',
#  '1451-р',
#  'требование',
#  'банк',
#  'договор',
#  'специальный',
#  'счёт',
#  'порядок',
#  'использование',
#  'иметься',
#  'участник',
#  'закупка',
#  'банковский',
#  'счёт',
#  'качество',
#  'специальный',
#  'счёт',
#  'правительство',
#  'рф',
#  'установить',
#  'постановление',
#  '30.05.2018',
#  '№626',
#  'независимый',
#  'гарантия',
#  'должный',
#  'соответствовать',
#  'требование',
#  'статья',
#  '45',
#  'закон',
#  '№',
#  '44-фз',
#  'реквизит',
#  'счёт',
#  'который',
#  'соответствие',
#  'законодательство',
#  'российский',
#  'федерация',
#  'учитываться',
#  'операция',
#  'средство',
#  'поступать',
#  'заказчик',
#  'наименование',
#  'заказчик',
#  'санкт-петербургский',
#  'государственный',
#  'бюджетный',
#  'учреждение',
#  'здравоохранение',
#  'городской',
#  'поликлиника',
#  '№',
#  '95',
#  'спб',
#  'гбуз',
#  'гп',
#  '№',
#  '95',
#  'реквизит',
#  'инна',
#  '7817026947',
#  'кпп',
#  '781701001',
#  'реквизит',
#  'банковский',
#  'счёт',
#  'северо-западный',
#  'гу',
#  'банк',
#  'россии//уфк',
#  'г.санкт-петербург',
#  'г.',
#  'санкт-петербург',
#  'бик',
#  '014030106',
#  'номер',
#  'счёт',
#  'банк',
#  'получатель',
#  '03224643400000007200',
#  'казначейский',
#  'счёт',
#  '40102810945370000005.',
#  'поставщик',
#  'должный',
#  'предоставить',
#  'обеспечение',
#  'исполнение',
#  'контракт',
#  'размер',
#  '10',
#  '%',
#  'цена',
#  'контракт',
#  'случай',
#  'обеспечение',
#  'исполнение',
#  'контракт',
#  'предоставляться',
#  'вид',
#  'передача',
#  'заказчик',
#  'денежный',
#  'средство',
#  'участник',
#  'запрос',
#  'котировка',
#  'электронный',
#  'форма',
#  'который',
#  'заключаться',
#  'контракт',
#  'перечислять',
#  'денежный',
#  'средство',
#  'счёт',
#  'спб',
#  'гбуз',
#  'гп',
#  '№95',
#  'инна',
#  '7817026947',
#  'кпп',
#  '781701001',
#  'получатель',
#  'платёж',
#  'комитет',
#  'финансы',
#  'спб',
#  'спб',
#  'гбуз',
#  'гп',
#  '№',
#  '95',
#  'л/с',
#  '0531015',
#  'реквизит',
#  'банковский',
#  'счёт',
#  'северо-западный',
#  'гу',
#  'банк',
#  'россии//уфк',
#  'г.',
#  'санкт-петербург',
#  'бик',
#  '014030106',
#  'номер',
#  'счёт',
#  'банк',
#  'получатель',
#  '03224643400000007200',
#  'к/с',
#  '40102810945370000005',
#  'поле',
#  '104',
#  'платёжный',
#  'документ',
#  'указываться',
#  'код',
#  'бюджетный',
#  'классификация',
#  'иметь',
#  '20',
#  'знак',
#  '00000000000000003510',
#  'платёжный',
#  'поручение',
#  'поле',
#  '``',
#  'назначение',
#  'платёж',
#  "''",
#  'указываться',
#  '510',
#  'вр',
#  '0531015',
#  'перечисление',
#  'обеспечение',
#  'контракт',
#  'предмет',
#  'контракт',
#  'номер',
#  'извещение',
#  'осуществление',
#  'закупка',
#  'ндс',
#  'обл',
#  'денежный',
#  'средство',
#  'внести',
#  'качество',
#  'обеспечение',
#  'исполнение',
#  'контракт',
#  'число',
#  'часть',
#  'этот',
#  'денежный',
#  'средство',
#  'случай',
#  'уменьшение',
#  'размер',
#  'обеспечение',
#  'исполнение',
#  'сведение',
#  'содержаться',
#  'котировочный',
#  'заявка',
#  'участник',
#  'должный',
#  'допускать',
#  'двусмысленный',
#  'толкование']

# %%
len(banks['texts'][1])
# Out:
# 254

# %%
len(banks['Sequences'][1])
# Out:
# 254

# %% [markdown]
# # Добавим искомые фразы в датасет в кодированном виде.

# %%
banks['quest']=banks['extracted_part'].values

# %%
banks['quest']
# Out:
# 0       {'text': ['Размер обеспечения исполнения контр...
# 1       {'text': ['Поставщик должен предоставить обесп...
# 2       {'text': ['Размер обеспечения исполнения контр...
# 3       {'text': ['Размер обеспечения исполнения контр...
# 4       {'text': ['Размер обеспечения исполнения контр...
#                               ...
# 1794    {'text': ['Заказчиком установлено требование о...
# 1795    {'text': [''], 'answer_start': [0], 'answer_en...
# 1796    {'text': [''], 'answer_start': [0], 'answer_en...
# 1797    {'text': [''], 'answer_start': [0], 'answer_en...
# 1798    {'text': [''], 'answer_start': [0], 'answer_en...
# Name: quest, Length: 1799, dtype: object

# %%
banks['quest'] = banks.apply(lambda row: dict(row['quest'])['text'], axis=1)

# %%
banks['quest']
# Out:
# 0       [Размер обеспечения исполнения контракта 6593....
# 1       [Поставщик должен предоставить обеспечение исп...
# 2        [Размер обеспечения исполнения контракта 10.00%]
# 3        [Размер обеспечения исполнения контракта 10.00%]
# 4        [Размер обеспечения исполнения контракта 10.00%]
#                               ...
# 1794    [Заказчиком установлено требование обеспечения...
# 1795                                                   []
# 1796                                                   []
# 1797                                                   []
# 1798                                                   []
# Name: quest, Length: 1799, dtype: object

# %%
banks['quest'] = banks.apply(lambda row: preprocess(str(row['quest']), punctuation_marks, stop_words, morph), axis=1)

# %%
banks['quest']
# Out:
# 0       [[, 'размер, обеспечение, исполнение, контракт...
# 1       [[, 'поставщик, должный, предоставить, обеспеч...
# 2       [[, 'размер, обеспечение, исполнение, контракт...
# 3       [[, 'размер, обеспечение, исполнение, контракт...
# 4       [[, 'размер, обеспечение, исполнение, контракт...
#                               ...
# 1794    [[, 'заказчик, установить, требование, обеспеч...
# 1795                                           [[, ``, ]]
# 1796                                           [[, ``, ]]
# 1797                                           [[, ``, ]]
# 1798                                           [[, ``, ]]
# Name: quest, Length: 1799, dtype: object

# %%
banks['quest'] = banks.apply(lambda row: text_to_sequence(row['quest'], word_to_index), axis=1)

# %%
banks['quest']
# Out:
# 0                 [191, 2, 4, 3, 7517, 43, 67, 3705, 169]
# 1       [191, 47, 112, 2, 4, 3, 14, 142, 35, 19, 3, 37...
# 2                      [191, 2, 4, 3, 724, 35, 3705, 169]
# 3                      [191, 2, 4, 3, 724, 35, 3705, 169]
# 4                      [191, 2, 4, 3, 724, 35, 3705, 169]
#                               ...
# 1794    [191, 69, 9, 2, 4, 5, 2, 4, 11, 8, 66, 35, 49,...
# 1795                                       [191, 22, 169]
# 1796                                       [191, 22, 169]
# 1797                                       [191, 22, 169]
# 1798                                       [191, 22, 169]
# Name: quest, Length: 1799, dtype: object

# %%
banks
# Out:
#              id                                               text  \
# 0     809436509  Извещение о проведении открытого конкурса в эл...
# 1     854885310  ТРЕБОВАНИЯ К СОДЕРЖАНИЮ ЗАЯВКИ участника запро...
# 2       4382157  Извещение о проведении электронного аукциона д...
# 3     184555082  Извещение о проведении электронного аукциона д...
# 4     211645258  Извещение о проведении электронного аукциона д...
# ...         ...                                                ...
# 1794  938335285  «УТВЕРЖДАЮ» Директор МУП "ПКП и ОРТ" _________...
# 1795  214609521  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ УНИТАРНОЕ ПРЕДПРИЯ...
# 1796   94811748  ДОГОВОР ПОДРЯДА № _____ «___»___________20____...
# 1797  903507299  ДОКУМЕНТАЦИЯ О ЗАКУПКЕ ЗАПРОС ПРЕДЛОЖЕНИЙ В ЭЛ...
# 1798  926039184  Государственная корпорацИя по атомной энергии ...
#
#                                      label  \
# 0         обеспечение исполнения контракта
# 1         обеспечение исполнения контракта
# 2         обеспечение исполнения контракта
# 3         обеспечение исполнения контракта
# 4         обеспечение исполнения контракта
# ...                                    ...
# 1794  обеспечение гарантийных обязательств
# 1795  обеспечение гарантийных обязательств
# 1796  обеспечение гарантийных обязательств
# 1797  обеспечение гарантийных обязательств
# 1798  обеспечение гарантийных обязательств
#
#                                          extracted_part  \
# 0     {'text': ['Размер обеспечения исполнения контр...
# 1     {'text': ['Поставщик должен предоставить обесп...
# 2     {'text': ['Размер обеспечения исполнения контр...
# 3     {'text': ['Размер обеспечения исполнения контр...
# 4     {'text': ['Размер обеспечения исполнения контр...
# ...                                                 ...
# 1794  {'text': ['Заказчиком установлено требование о...
# 1795  {'text': [''], 'answer_start': [0], 'answer_en...
# 1796  {'text': [''], 'answer_start': [0], 'answer_en...
# 1797  {'text': [''], 'answer_start': [0], 'answer_en...
# 1798  {'text': [''], 'answer_start': [0], 'answer_en...
#
#                                                   texts  \
# 0     [извещение, проведение, открытый, конкурс, эле...
# 1     [требование, содержание, заявка, участник, зап...
# 2     [извещение, проведение, электронный, аукцион, ...
# 3     [извещение, проведение, электронный, аукцион, ...
# 4     [извещение, проведение, электронный, аукцион, ...
# ...                                                 ...
# 1794  [утверждать, директор, муп, ``, пкп, орт, '', ...
# 1795  [федеральный, государственный, унитарный, пред...
# 1796  [договор, подряд, №, _____, ___, ___________20...
# 1797  [документация, закупка, запрос, предложение, э...
# 1798  [государственный, корпорация, атомный, энергия...
#
#                                               Sequences  \
# 0     [33, 52, 269, 302, 29, 48, 6, 7515, 107, 46, 3...
# 1     [9, 244, 31, 17, 87, 114, 29, 48, 31, 76, 87, ...
# 2     [33, 52, 29, 54, 6, 7522, 107, 46, 34, 33, 752...
# 3     [33, 52, 29, 54, 6, 7534, 107, 46, 34, 33, 753...
# 4     [33, 52, 29, 54, 6, 7537, 107, 46, 34, 33, 753...
# ...                                                 ...
# 1794  [161, 179, 628, 22, 5997, 5998, 23, 1410, 2542...
# 1795  [37, 51, 338, 308, 1088, 1955, 4934, 161, 677,...
# 1796  [5, 965, 12, 407, 128, 7334, 357, 572, 1584, 1...
# 1797  [58, 6, 87, 131, 29, 48, 181, 75, 5, 213, 32, ...
# 1798  [51, 883, 652, 984, 732, 447, 334, 2901, 2609,...
#
#                                                   quest
# 0               [191, 2, 4, 3, 7517, 43, 67, 3705, 169]
# 1     [191, 47, 112, 2, 4, 3, 14, 142, 35, 19, 3, 37...
# 2                    [191, 2, 4, 3, 724, 35, 3705, 169]
# 3                    [191, 2, 4, 3, 724, 35, 3705, 169]
# 4                    [191, 2, 4, 3, 724, 35, 3705, 169]
# ...                                                 ...
# 1794  [191, 69, 9, 2, 4, 5, 2, 4, 11, 8, 66, 35, 49,...
# 1795                                     [191, 22, 169]
# 1796                                     [191, 22, 169]
# 1797                                     [191, 22, 169]
# 1798                                     [191, 22, 169]
#
# [1799 rows x 7 columns]

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# %%
x_train = vectorize_sequences(banks['Sequences'])
y_train = vectorize_sequences(banks['quest'])

# %%
x_train.shape
# Out:
# (1799, 10000)

# %%
y_train.shape
# Out:
# (1799, 10000)

# %%
import tensorflow as tf 
import tensorflow as tf 
from keras import models
from keras import layers


def build_model():
    model = tf.keras.Sequential([
    tf.keras.layers.Dense(10000,input_shape=(10000,)),
    tf.keras.layers.Dense(200, activation='relu'),  
    tf.keras.layers.Dense(100, activation='relu'), 
    tf.keras.layers.Dense(50, activation='relu'), 
    tf.keras.layers.Dense(320000)

])
    model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(),metrics=['accuracy'])

    return model

model = build_model()


history = model.fit(x_train,y_train,
                    epochs=20, 
                    )
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In [95], line 23
#      18     return model
#      20 model = build_model()
# ---> 23 history = model.fit(x_train,y_train,
#      24                     epochs=20,
#      25                     )
#
# File ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/home/genalll/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/genalll/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 982, in launch_instance
#       app.start()
#     File "/home/genalll/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/home/genalll/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#       handle._run()
#     File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/genalll/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/home/genalll/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/home/genalll/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/home/genalll/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/home/genalll/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/home/genalll/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/genalll/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2940, in run_cell
#       result = self._run_cell(
#     File "/home/genalll/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2995, in _run_cell
#       return runner(coro)
#     File "/home/genalll/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/genalll/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3194, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/genalll/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3373, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/genalll/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3433, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_24788/3850338170.py", line 23, in <module>
#       history = model.fit(x_train,y_train,
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/engine/training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/engine/training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/engine/training.py", line 1024, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/engine/training.py", line 1082, in compute_loss
#       return self.compiled_loss(
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/engine/compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/losses.py", line 152, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/losses.py", line 284, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/losses.py", line 2098, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "/home/genalll/.local/lib/python3.8/site-packages/keras/backend.py", line 5633, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# logits and labels must have the same first dimension, got logits shape [32,320000] and labels shape [320000]
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]] [Op:__inference_train_function_15876]
